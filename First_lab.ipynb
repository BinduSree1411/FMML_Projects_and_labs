# %%
# Transpose of a matrix from scratch
# def transpose_matrix(matrix):
#     rows = len(matrix)
#     cols = len(matrix[0]) if rows > 0 else 0

#     transposed = [[0 for _ in range(rows)] for _ in range(cols)]

#     for i in range(rows):
#         for j in range(cols):
#             transposed[j][i] = matrix[i][j]
#     return transposed

# matrix = [[2, 4, 6], [1, 3, 5], [7, 8, 9]]
# matrix = transpose_matrix(matrix)
# print(matrix)
#[[2, 1, 7], [4, 3, 8], [6, 5, 9]] Answer




#Dot product from Scratch
# a = [5, 7, 6]
# b = [2, 3, 6]
# dot_product = 0
# for i in range(len(a)):
#     dot_product += a[i] * b[i]
# print(dot_product)
#67 Answer





#Outer Product
# def outer_product(a,b):
#     result= []
#     for i in range(len(a)):
#         row = []
#         for j in range(len(b)):
#             row.append(a[i] * b[j])
#         result.append(row)
#     return result
# a= [8, 7, 6]
# b= [5, 4, 3]
# result = outer_product(a,b)
# for row in result:
#     print(row)
# [40, 32, 24]
# [35, 28, 21]
# [30, 24, 18] Answer





#Matrix multiplication from Scratch
# def matrix_multiplication(a, b):
#     rows_a = len(a)
#     cols_a = len(a[0])
#     cols_b = len(b[0])

#     result = [[0 for _ in range(cols_b)] for _ in range(rows_a)]

#     for i in range(rows_a):
#         for j in range(cols_b):
#             for k in range(cols_a):
#                 result[i][j] += a[i][k] * b[k][j]
#     return result
# a = [[5, 4, 3], [8, 5, 7]]
# b = [[3, 5], [4, 3], [1,3]]

# result = matrix_multiplication(a, b)
# for row in result:
#     print(row)
#[34, 46]
#[51, 76] Answer





#Determinant of a matrix
# def determinant(matrix):
#     return matrix[0][0]*matrix[1][1] - matrix[0][1]*matrix[1][0]
# A = [[2, 7], [4, 5]]
# print("Determinant:", determinant(a))
#-7 Answer




#Inverse Of a Matrix
# def determinant(matrix):
#     return matrix[0][0]*matrix[1][1] - matrix[0][1]*matrix[1][0]

# def inverse(matrix):
#     det = determinant(matrix)
#     if det == 0:
#         return "Matrix is singular"
#     return [
#         [ matrix[1][1]/det, -matrix[0][1]/det],
#         [-matrix[1][0]/det,  matrix[0][0]/det]
#     ]

# a = [[2, 7], [4, 5]]
# inv = inverse(a)
# print("inverse:")
# for row in inv:
#     print(row)
#inverse:
# [-0.2777777777777778, 0.3888888888888889]
# [0.2222222222222222, -0.1111111111111111] Answer




#Trace of a Matrix
# def trace(matrix):
#     return sum(matrix[i][i] for i in range(len(matrix)))

# a = [[2, 7], [4, 5]]
# print("Trace:", trace(a))
#7 Answer





#Matrix Norm
# def matrix_norm(matrix):
#     total = 0
#     for row in matrix:
#         for val in row:
#             total += val**2
#     return total ** 0.5
# a = [[2,7], [4,5]]
# print("Matrix Norm:", matrix_norm(a))
#Matrix Norm: 9.695359714832659 Answer
# Out:
# Matrix Norm: 9.695359714832659
